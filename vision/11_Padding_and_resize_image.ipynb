# %%
import os
import cv2
import numpy as np
import os
from PIL import Image

# %%
base_path = 'E:\\Test_vision\\test\\'

# %%
def createFolder(crops, sub_folder):
       nameFolder = 'padding_' + sub_folder
       pading_folder = crops + nameFolder
       try:
              os.mkdir(pading_folder)
              print("Directory", nameFolder, "Created")
       except FileExistsError:
              print("Directory", nameFolder, "already exists")
       return pading_folder + '\\'

# %%
def padding(old_image_width, old_image_height, new_image_width, new_image_height):
       x_center = (new_image_width - old_image_width) // 2
       y_center = (new_image_height - old_image_height) // 2
       return x_center, y_center

# %%
for subtype_folder in os.listdir(base_path):
    yolo_subtype_path = base_path + subtype_folder + '\\'
    for mainfile_folder in os.listdir(yolo_subtype_path):
        yolo_mainfile_path = yolo_subtype_path + mainfile_folder + '\\'
        for subfile in os.listdir(yolo_mainfile_path):
            yolo_subfile_path = yolo_mainfile_path + subfile + '\\' + 'Humand hand' + '\\'
            vision_yolo_path = base_path + '\\' + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\' + 'Humand hand' + '\\'
            for yolo_folder in os.listdir(vision_yolo_path):
                vision_yolo_subfolder_path = vision_yolo_path + '\\' + yolo_folder + '\\'
                for vision_yolo_file in os.listdir(vision_yolo_subfolder_path):
                    vision_yolo_file_path = base_path  + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\Humand hand\\' + yolo_folder + '\\' + vision_yolo_file

                    crops =  base_path  + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\Humand hand\\' + yolo_folder + '\\'
                    pading_folder = createFolder(crops, vision_yolo_file)

                    for (root, dirs, file) in os.walk(crops):
                       for images in file:
                              frames = Image.open(crops+images)
                              # get width and height
                              print(crops+images, ' = ', frames.size)

                              # read image
                              img = cv2.imread(crops+images)
                              old_image_height, old_image_width, channels = img.shape
                              print('Old size ===> ({}, {}, {})'.format(old_image_width, old_image_height, channels))

                              # create new image of desired size and color (blue) for padding
                              new_image_width = 224   # change width size
                              new_image_height = 224  # change height size
                              new_size = (new_image_width,new_image_height)
                              color = (0, 0, 0)  ### white (255,255,255)
                              result = np.full((new_image_height, new_image_width, channels), color,dtype=np.uint8)

                              if (old_image_width < new_image_width) and (old_image_height < new_image_height) :
                                    # print('case  1')
                                     # # copy img image into center of result image
                                     x_center, y_center = padding(old_image_width, old_image_height,new_image_width, new_image_height)
                                     result[y_center:y_center + old_image_height,
                                     x_center:x_center + old_image_width] = img
                                     cv2.imwrite(pading_folder+images, result)
                                     print('Case 1 ===> New shape (w, h) = {}'.format(result.shape))

                              elif (old_image_width > new_image_width) and (old_image_height < new_image_height) :
                                     # print('case 2')
                                     x_resize = cv2.resize(img, (new_image_width, old_image_height))
                                 #    print('Old size (w, h) = '.format(x_resize.shape[1], x_resize.shape[0]))
                                 #    cv2.imwrite("case2_resize.jpg", x_resize)

                                     old_image_height, old_image_width, channels = x_resize.shape

                                     # compute center offset
                                     x_center, y_center = padding(old_image_width, old_image_height,
                                                                  new_image_width, new_image_height)

                                     result[y_center:y_center + old_image_height,
                                     x_center:x_center + old_image_width] = x_resize

                                     cv2.imwrite(pading_folder+images, result)
                                     print('Case 2 ===>  New shape (w, h) = {}'.format(result.shape))

                              elif (old_image_width < new_image_width) and (old_image_height > new_image_height) :
                                     # print('case 3')
                                     y_resize = cv2.resize(img, (old_image_width, new_image_height))
                                   #  print('Old size (w, h) = '.format(y_resize.shape[1], y_resize.shape[0]))
                                  #   cv2.imwrite("case3_resize.jpg", y_resize)

                                     old_image_height, old_image_width, channels = y_resize.shape

                                     # compute center offset
                                     x_center, y_center = padding(old_image_width, old_image_height,
                                                                  new_image_width, new_image_height)

                                     result[y_center:y_center + old_image_height,
                                     x_center:x_center + old_image_width] = y_resize

                                     cv2.imwrite(pading_folder+images, result)
                                     print('Case 3 ===>  New shape (w, h) = {}'.format(result.shape))
                              else:
                                     # print('case 4')
                                  #   print('case  4  => Old size (w, h) = {}, {}'.format(old_image_width, old_image_height))
                                     xy_resize = cv2.resize(img, (new_image_width, new_image_height))
                                     cv2.imwrite(pading_folder+images, xy_resize)
                                     print('Case 4 ===>  New shape (w, h) = {}'.format(xy_resize.shape))
                       print('')
# Out:
# Directory padding_อ่-1.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-1\อ่-1.jpg  =  (103, 93)
# Old size ===> (103, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-1\อ่-1.jpg  =  (103, 93)
# Old size ===> (103, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-10.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-10.jpg  =  (175, 252)
# Old size ===> (175, 252, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-102.jpg  =  (162, 199)
# Old size ===> (162, 199, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-10.jpg  =  (175, 252)
# Old size ===> (175, 252, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-102.jpg  =  (162, 199)
# Old size ===> (162, 199, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-102.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-10.jpg  =  (175, 252)
# Old size ===> (175, 252, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-102.jpg  =  (162, 199)
# Old size ===> (162, 199, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-10.jpg  =  (175, 252)
# Old size ===> (175, 252, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-102.jpg  =  (162, 199)
# Old size ===> (162, 199, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-10.jpg  =  (175, 252)
# Old size ===> (175, 252, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-10\อ่-102.jpg  =  (162, 199)
# Old size ===> (162, 199, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-11.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-11.jpg  =  (173, 251)
# Old size ===> (173, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-112.jpg  =  (164, 194)
# Old size ===> (164, 194, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-11.jpg  =  (173, 251)
# Old size ===> (173, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-112.jpg  =  (164, 194)
# Old size ===> (164, 194, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-112.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-11.jpg  =  (173, 251)
# Old size ===> (173, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-112.jpg  =  (164, 194)
# Old size ===> (164, 194, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-11.jpg  =  (173, 251)
# Old size ===> (173, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-112.jpg  =  (164, 194)
# Old size ===> (164, 194, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-11.jpg  =  (173, 251)
# Old size ===> (173, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-11\อ่-112.jpg  =  (164, 194)
# Old size ===> (164, 194, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-12.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-12.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-122.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-12.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-122.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-122.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-12.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-122.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-12.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-122.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-12.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-12\อ่-122.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-13.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-13.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-132.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-13.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-132.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-132.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-13.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-132.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-13.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-132.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-13.jpg  =  (172, 249)
# Old size ===> (172, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-13\อ่-132.jpg  =  (176, 192)
# Old size ===> (176, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-14.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-14.jpg  =  (169, 248)
# Old size ===> (169, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-142.jpg  =  (191, 182)
# Old size ===> (191, 182, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-14.jpg  =  (169, 248)
# Old size ===> (169, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-142.jpg  =  (191, 182)
# Old size ===> (191, 182, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-142.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-14.jpg  =  (169, 248)
# Old size ===> (169, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-142.jpg  =  (191, 182)
# Old size ===> (191, 182, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-14.jpg  =  (169, 248)
# Old size ===> (169, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-142.jpg  =  (191, 182)
# Old size ===> (191, 182, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-14.jpg  =  (169, 248)
# Old size ===> (169, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-14\อ่-142.jpg  =  (191, 182)
# Old size ===> (191, 182, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-15.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-15\อ่-15.jpg  =  (168, 249)
# Old size ===> (168, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-15\อ่-15.jpg  =  (168, 249)
# Old size ===> (168, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-16.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-16\อ่-16.jpg  =  (168, 249)
# Old size ===> (168, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-16\อ่-16.jpg  =  (168, 249)
# Old size ===> (168, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-17.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-17.jpg  =  (220, 133)
# Old size ===> (220, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-172.jpg  =  (163, 244)
# Old size ===> (163, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-17.jpg  =  (220, 133)
# Old size ===> (220, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-172.jpg  =  (163, 244)
# Old size ===> (163, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-172.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-17.jpg  =  (220, 133)
# Old size ===> (220, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-172.jpg  =  (163, 244)
# Old size ===> (163, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-17.jpg  =  (220, 133)
# Old size ===> (220, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-172.jpg  =  (163, 244)
# Old size ===> (163, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-17.jpg  =  (220, 133)
# Old size ===> (220, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-17\อ่-172.jpg  =  (163, 244)
# Old size ===> (163, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-18.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-18.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-182.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-18.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-182.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-182.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-18.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-182.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-18.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-182.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-18.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-18\อ่-182.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-19.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-19.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-192.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-19.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-192.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-192.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-19.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-192.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-19.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-192.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-19.jpg  =  (167, 247)
# Old size ===> (167, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-19\อ่-192.jpg  =  (184, 122)
# Old size ===> (184, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-2.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-2.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-22.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-2.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-22.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-22.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-2.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-22.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-2.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-22.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-2.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-2\อ่-22.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-20.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-20.jpg  =  (172, 255)
# Old size ===> (172, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-202.jpg  =  (175, 122)
# Old size ===> (175, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-20.jpg  =  (172, 255)
# Old size ===> (172, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-202.jpg  =  (175, 122)
# Old size ===> (175, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-202.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-20.jpg  =  (172, 255)
# Old size ===> (172, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-202.jpg  =  (175, 122)
# Old size ===> (175, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-20.jpg  =  (172, 255)
# Old size ===> (172, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-202.jpg  =  (175, 122)
# Old size ===> (175, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-20.jpg  =  (172, 255)
# Old size ===> (172, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-20\อ่-202.jpg  =  (175, 122)
# Old size ===> (175, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-21.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-21.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-212.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-21.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-212.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-212.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-21.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-212.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-21.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-212.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-21.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-21\อ่-212.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-22.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-22.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-222.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-22.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-222.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-222.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-22.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-222.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-22.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-222.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-22.jpg  =  (170, 244)
# Old size ===> (170, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-22\อ่-222.jpg  =  (194, 120)
# Old size ===> (194, 120, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-23.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-23.jpg  =  (217, 122)
# Old size ===> (217, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-232.jpg  =  (171, 247)
# Old size ===> (171, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-23.jpg  =  (217, 122)
# Old size ===> (217, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-232.jpg  =  (171, 247)
# Old size ===> (171, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-232.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-23.jpg  =  (217, 122)
# Old size ===> (217, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-232.jpg  =  (171, 247)
# Old size ===> (171, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-23.jpg  =  (217, 122)
# Old size ===> (217, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-232.jpg  =  (171, 247)
# Old size ===> (171, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-23.jpg  =  (217, 122)
# Old size ===> (217, 122, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-23\อ่-232.jpg  =  (171, 247)
# Old size ===> (171, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-24.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-24.jpg  =  (233, 120)
# Old size ===> (233, 120, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-242.jpg  =  (173, 244)
# Old size ===> (173, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-24.jpg  =  (233, 120)
# Old size ===> (233, 120, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-242.jpg  =  (173, 244)
# Old size ===> (173, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-242.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-24.jpg  =  (233, 120)
# Old size ===> (233, 120, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-242.jpg  =  (173, 244)
# Old size ===> (173, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-24.jpg  =  (233, 120)
# Old size ===> (233, 120, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-242.jpg  =  (173, 244)
# Old size ===> (173, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-24.jpg  =  (233, 120)
# Old size ===> (233, 120, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-24\อ่-242.jpg  =  (173, 244)
# Old size ===> (173, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-25.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-25.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-252.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-25.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-252.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-252.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-25.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-252.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-25.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-252.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-25.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-25\อ่-252.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-26.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-26.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-262.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-26.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-262.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-262.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-26.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-262.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-26.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-262.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-26.jpg  =  (232, 117)
# Old size ===> (232, 117, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-26\อ่-262.jpg  =  (173, 255)
# Old size ===> (173, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-27.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-27.jpg  =  (175, 261)
# Old size ===> (175, 261, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-272.jpg  =  (229, 116)
# Old size ===> (229, 116, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-27.jpg  =  (175, 261)
# Old size ===> (175, 261, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-272.jpg  =  (229, 116)
# Old size ===> (229, 116, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-272.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-27.jpg  =  (175, 261)
# Old size ===> (175, 261, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-272.jpg  =  (229, 116)
# Old size ===> (229, 116, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-27.jpg  =  (175, 261)
# Old size ===> (175, 261, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-272.jpg  =  (229, 116)
# Old size ===> (229, 116, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-27.jpg  =  (175, 261)
# Old size ===> (175, 261, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-27\อ่-272.jpg  =  (229, 116)
# Old size ===> (229, 116, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-28.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-28.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-282.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-28.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-282.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-282.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-28.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-282.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-28.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-282.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-28.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-28\อ่-282.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-29.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-29.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-292.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-29.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-292.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-292.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-29.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-292.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-29.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-292.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-29.jpg  =  (174, 270)
# Old size ===> (174, 270, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-29\อ่-292.jpg  =  (231, 105)
# Old size ===> (231, 105, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-3.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-3.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-32.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-3.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-32.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-32.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-3.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-32.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-3.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-32.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-3.jpg  =  (181, 197)
# Old size ===> (181, 197, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-3\อ่-32.jpg  =  (174, 149)
# Old size ===> (174, 149, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-30.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-30.jpg  =  (176, 285)
# Old size ===> (176, 285, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-302.jpg  =  (217, 93)
# Old size ===> (217, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-30.jpg  =  (176, 285)
# Old size ===> (176, 285, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-302.jpg  =  (217, 93)
# Old size ===> (217, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-302.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-30.jpg  =  (176, 285)
# Old size ===> (176, 285, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-302.jpg  =  (217, 93)
# Old size ===> (217, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-30.jpg  =  (176, 285)
# Old size ===> (176, 285, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-302.jpg  =  (217, 93)
# Old size ===> (217, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-30.jpg  =  (176, 285)
# Old size ===> (176, 285, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-30\อ่-302.jpg  =  (217, 93)
# Old size ===> (217, 93, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-31.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-31.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-312.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-31.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-312.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-312.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-31.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-312.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-31.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-312.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-31.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-31\อ่-312.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-32.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-32.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-322.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-32.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-322.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-322.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-32.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-322.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-32.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-322.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-32.jpg  =  (173, 276)
# Old size ===> (173, 276, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-32\อ่-322.jpg  =  (221, 85)
# Old size ===> (221, 85, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-33.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-33.jpg  =  (193, 71)
# Old size ===> (193, 71, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-332.jpg  =  (178, 265)
# Old size ===> (178, 265, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-33.jpg  =  (193, 71)
# Old size ===> (193, 71, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-332.jpg  =  (178, 265)
# Old size ===> (178, 265, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-332.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-33.jpg  =  (193, 71)
# Old size ===> (193, 71, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-332.jpg  =  (178, 265)
# Old size ===> (178, 265, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-33.jpg  =  (193, 71)
# Old size ===> (193, 71, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-332.jpg  =  (178, 265)
# Old size ===> (178, 265, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-33.jpg  =  (193, 71)
# Old size ===> (193, 71, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-33\อ่-332.jpg  =  (178, 265)
# Old size ===> (178, 265, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-34.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-34\อ่-34.jpg  =  (177, 257)
# Old size ===> (177, 257, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-34\อ่-34.jpg  =  (177, 257)
# Old size ===> (177, 257, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-35.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-35\อ่-35.jpg  =  (177, 257)
# Old size ===> (177, 257, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-35\อ่-35.jpg  =  (177, 257)
# Old size ===> (177, 257, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-36.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-36\อ่-36.jpg  =  (172, 231)
# Old size ===> (172, 231, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-36\อ่-36.jpg  =  (172, 231)
# Old size ===> (172, 231, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-37.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-37\อ่-37.jpg  =  (146, 161)
# Old size ===> (146, 161, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-37\อ่-37.jpg  =  (146, 161)
# Old size ===> (146, 161, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-38.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-38\อ่-38.jpg  =  (133, 112)
# Old size ===> (133, 112, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-38\อ่-38.jpg  =  (133, 112)
# Old size ===> (133, 112, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-39.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-39\อ่-39.jpg  =  (133, 112)
# Old size ===> (133, 112, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-39\อ่-39.jpg  =  (133, 112)
# Old size ===> (133, 112, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-4.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-4.jpg  =  (175, 185)
# Old size ===> (175, 185, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-42.jpg  =  (182, 192)
# Old size ===> (182, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-4.jpg  =  (175, 185)
# Old size ===> (175, 185, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-42.jpg  =  (182, 192)
# Old size ===> (182, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-42.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-4.jpg  =  (175, 185)
# Old size ===> (175, 185, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-42.jpg  =  (182, 192)
# Old size ===> (182, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-4.jpg  =  (175, 185)
# Old size ===> (175, 185, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-42.jpg  =  (182, 192)
# Old size ===> (182, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-4.jpg  =  (175, 185)
# Old size ===> (175, 185, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-4\อ่-42.jpg  =  (182, 192)
# Old size ===> (182, 192, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-5.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-5.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-52.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-5.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-52.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-52.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-5.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-52.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-5.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-52.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-5.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-5\อ่-52.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-6.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-6.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-62.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-6.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-62.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-62.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-6.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-62.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-6.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-62.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-6.jpg  =  (168, 203)
# Old size ===> (168, 203, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-6\อ่-62.jpg  =  (177, 224)
# Old size ===> (177, 224, 3)
# Case 4 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-7.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-7.jpg  =  (175, 241)
# Old size ===> (175, 241, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-72.jpg  =  (157, 195)
# Old size ===> (157, 195, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-7.jpg  =  (175, 241)
# Old size ===> (175, 241, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-72.jpg  =  (157, 195)
# Old size ===> (157, 195, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ่-72.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-7.jpg  =  (175, 241)
# Old size ===> (175, 241, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ่\อ่_1\Humand hand\อ่-7\อ่-72.jpg  =  (157, 195)
# Old size ===> (157, 195, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# ...
# Old size ===> (186, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-37.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-37.jpg  =  (212, 247)
# Old size ===> (212, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-372.jpg  =  (178, 133)
# Old size ===> (178, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-37.jpg  =  (212, 247)
# Old size ===> (212, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-372.jpg  =  (178, 133)
# Old size ===> (178, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-372.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-37.jpg  =  (212, 247)
# Old size ===> (212, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-372.jpg  =  (178, 133)
# Old size ===> (178, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-37.jpg  =  (212, 247)
# Old size ===> (212, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-372.jpg  =  (178, 133)
# Old size ===> (178, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-37.jpg  =  (212, 247)
# Old size ===> (212, 247, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-37\อ้-372.jpg  =  (178, 133)
# Old size ===> (178, 133, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-38.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-38.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-382.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-38.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-382.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-382.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-38.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-382.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-38.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-382.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-38.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-38\อ้-382.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-39.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-39.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-392.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-39.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-392.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-392.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-39.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-392.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-39.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-392.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-39.jpg  =  (214, 248)
# Old size ===> (214, 248, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-39\อ้-392.jpg  =  (182, 138)
# Old size ===> (182, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-40.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-40.jpg  =  (214, 243)
# Old size ===> (214, 243, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-402.jpg  =  (211, 138)
# Old size ===> (211, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-40.jpg  =  (214, 243)
# Old size ===> (214, 243, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-402.jpg  =  (211, 138)
# Old size ===> (211, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-402.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-40.jpg  =  (214, 243)
# Old size ===> (214, 243, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-402.jpg  =  (211, 138)
# Old size ===> (211, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-40.jpg  =  (214, 243)
# Old size ===> (214, 243, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-402.jpg  =  (211, 138)
# Old size ===> (211, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-40.jpg  =  (214, 243)
# Old size ===> (214, 243, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-40\อ้-402.jpg  =  (211, 138)
# Old size ===> (211, 138, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-41.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-41.jpg  =  (216, 237)
# Old size ===> (216, 237, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-412.jpg  =  (207, 142)
# Old size ===> (207, 142, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-41.jpg  =  (216, 237)
# Old size ===> (216, 237, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-412.jpg  =  (207, 142)
# Old size ===> (207, 142, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-412.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-41.jpg  =  (216, 237)
# Old size ===> (216, 237, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-412.jpg  =  (207, 142)
# Old size ===> (207, 142, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-41.jpg  =  (216, 237)
# Old size ===> (216, 237, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-412.jpg  =  (207, 142)
# Old size ===> (207, 142, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-41.jpg  =  (216, 237)
# Old size ===> (216, 237, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-41\อ้-412.jpg  =  (207, 142)
# Old size ===> (207, 142, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-42.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-42.jpg  =  (216, 249)
# Old size ===> (216, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-422.jpg  =  (205, 136)
# Old size ===> (205, 136, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-42.jpg  =  (216, 249)
# Old size ===> (216, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-422.jpg  =  (205, 136)
# Old size ===> (205, 136, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-422.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-42.jpg  =  (216, 249)
# Old size ===> (216, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-422.jpg  =  (205, 136)
# Old size ===> (205, 136, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-42.jpg  =  (216, 249)
# Old size ===> (216, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-422.jpg  =  (205, 136)
# Old size ===> (205, 136, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-42.jpg  =  (216, 249)
# Old size ===> (216, 249, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-42\อ้-422.jpg  =  (205, 136)
# Old size ===> (205, 136, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-43.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-43.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-432.jpg  =  (209, 109)
# Old size ===> (209, 109, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-43.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-432.jpg  =  (209, 109)
# Old size ===> (209, 109, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-432.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-43.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-432.jpg  =  (209, 109)
# Old size ===> (209, 109, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-43.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-432.jpg  =  (209, 109)
# Old size ===> (209, 109, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-43.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-43\อ้-432.jpg  =  (209, 109)
# Old size ===> (209, 109, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-44.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-44\อ้-44.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-44\อ้-44.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-45.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-45\อ้-45.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-45\อ้-45.jpg  =  (212, 255)
# Old size ===> (212, 255, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-46.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-46\อ้-46.jpg  =  (214, 251)
# Old size ===> (214, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-46\อ้-46.jpg  =  (214, 251)
# Old size ===> (214, 251, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-47.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-47\อ้-47.jpg  =  (210, 244)
# Old size ===> (210, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-47\อ้-47.jpg  =  (210, 244)
# Old size ===> (210, 244, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-48.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-48\อ้-48.jpg  =  (211, 232)
# Old size ===> (211, 232, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-48\อ้-48.jpg  =  (211, 232)
# Old size ===> (211, 232, 3)
# Case 3 ===>  New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-49.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-49\อ้-49.jpg  =  (214, 213)
# Old size ===> (214, 213, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-49\อ้-49.jpg  =  (214, 213)
# Old size ===> (214, 213, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-50.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-50\อ้-50.jpg  =  (214, 213)
# Old size ===> (214, 213, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-50\อ้-50.jpg  =  (214, 213)
# Old size ===> (214, 213, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-51.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-51\อ้-51.jpg  =  (209, 188)
# Old size ===> (209, 188, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-51\อ้-51.jpg  =  (209, 188)
# Old size ===> (209, 188, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-52.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-52\อ้-52.jpg  =  (205, 160)
# Old size ===> (205, 160, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-52\อ้-52.jpg  =  (205, 160)
# Old size ===> (205, 160, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-53.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-53\อ้-53.jpg  =  (164, 118)
# Old size ===> (164, 118, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-53\อ้-53.jpg  =  (164, 118)
# Old size ===> (164, 118, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-54.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-54\อ้-54.jpg  =  (165, 66)
# Old size ===> (165, 66, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-54\อ้-54.jpg  =  (165, 66)
# Old size ===> (165, 66, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-8.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-8\อ้-8.jpg  =  (186, 121)
# Old size ===> (186, 121, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-8\อ้-8.jpg  =  (186, 121)
# Old size ===> (186, 121, 3)
# Case 1 ===> New shape (w, h) = (224, 224, 3)
#
# Directory padding_อ้-9.jpg Created
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-9\อ้-9.jpg  =  (225, 173)
# Old size ===> (225, 173, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
#
# E:\Test_vision\test\วรรณยุกต์\อ้\อ้_6\Humand hand\อ้-9\อ้-9.jpg  =  (225, 173)
# Old size ===> (225, 173, 3)
# Case 2 ===>  New shape (w, h) = (224, 224, 3)
