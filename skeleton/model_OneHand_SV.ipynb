# %%
# !pip3 install pandas
# !pip3 install matplotlib
# !pip install seaborn
# !pip3 install plotly
# !pip3 install pandas_profiling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import plotly as cm
from pandas_profiling import ProfileReport

# %%
srcfile = '/home/s2120006/TFS/skeleton/TFS_OneHand_54_points_no_V.csv'

# %%
# df = pd.read_csv(srcfile, sep=';', encoding='latin1')
# df.head()
# Out:
#   class,x1,y1,z1,x2,y2,z2,x3,y3,z3,x4,y4,z4,x5,y5,z5,x6,y6,z6,x7,y7,z7,x8,y8,z8,x9,y9,z9,x10,y10,z10,x11,y11,z11,x12,y12,z12,x13,y13,z13,x14,y14,z14,x15,y15,z15,x16,y16,z16,x17,y17,z17,x18,y18,z18,x19,y19,z19,x20,y20,z20,x21,y21,z21,x22,y22,z22,x23,y23,z23,x24,y24,z24,x25,y25,z25,x26,y26,z26,x27,y27,z27,x28,y28,z28,x29,y29,z29,x30,y30,z30,x31,y31,z31,x32,y32,z32,x33,y33,z33,x34,y34,z34,x35,y35,z35,x36,y36,z36,x37,y37,z37,x38,y38,z38,x39,y39,z39,x40,y40,z40,x41,y41,z41,x42,y42,z42,x43,y43,z43,x44,y44,z44,x45,y45,z45,x46,y46,z46,x47,y47,z47,x48,y48,z48,x49,y49,z49,x50,y50,z50,x51,y51,z51,x52,y52,z52,x53,y53,z53,x54,y54,z54
# 0  0,0.469715416431427,0.44084692001342773,-1.146...
# 1  0,0.47087952494621277,0.4315831661224365,-1.01...
# 2  0,0.47087952494621277,0.4315831661224365,-1.01...
# 3  0,0.46131324768066406,0.44172096252441406,-0.8...
# 4  0,0.4620087444782257,0.43432268500328064,-0.95...

# %%
# profile = ProfileReport(df, title = 'TFS-Skeleton-Onehand_54_points')
# profile

# %%
# print(df.isnull().sum())

# %%
# df.head()

# %%
df = pd.read_csv(srcfile, engine='python')

# %%
df.head()
# Out:
#   class        x1        y1        z1        x2        y2        z2        x3  \
# 0     0  0.469715  0.440847 -1.146045  0.492933  0.367618 -1.074119  0.506275
# 1     0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780  0.505930
# 2     0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780  0.505930
# 3     0  0.461313  0.441721 -0.895512  0.490067  0.364946 -0.815676  0.505128
# 4     0  0.462009  0.434323 -0.954978  0.490552  0.357484 -0.868968  0.504614
#
#          y3        z3  ...       z51       x52       y52       z52       x53  \
# 0  0.367054 -1.074444  ... -0.053524  0.399725  0.730864 -0.062620  0.427866
# 1  0.352796 -0.929152  ... -0.048000  0.398512  0.606266 -0.058852  0.428957
# 2  0.352796 -0.929152  ... -0.048000  0.398512  0.606266 -0.058852  0.428957
# 3  0.363007 -0.816117  ... -0.038509  0.395845  0.572608 -0.049951  0.427251
# 4  0.355328 -0.869323  ... -0.038847  0.392572  0.538630 -0.047879  0.424092
#
#         y53       z53       x54       y54       z54
# 0  0.751528 -0.060393  0.447253  0.774449 -0.058090
# 1  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 2  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 3  0.590068 -0.049887  0.448360  0.611298 -0.047701
# 4  0.548410 -0.046750  0.444159  0.566794 -0.043640
#
# [5 rows x 163 columns]

# %%
df.tail()
# Out:
#        class        x1        y1        z1        x2        y2        z2  \
# 150095    ไอ  0.528125  0.373132 -0.992049  0.547567  0.315567 -0.916250
# 150096    ไอ  0.525108  0.370276 -0.992426  0.546147  0.315484 -0.917663
# 150097    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150098    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150099    ไอ  0.524986  0.361204 -1.097511  0.544687  0.304384 -1.024949
#
#               x3        y3        z3  ...       z51       x52       y52  \
# 150095  0.562286  0.317489 -0.916352  ... -0.028968  0.291391  0.640639
# 150096  0.561741  0.318271 -0.917825  ... -0.037876  0.269125  0.701057
# 150097  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150098  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150099  0.559115  0.306688 -1.025168  ... -0.031130  0.237031  0.866545
#
#              z52       x53       y53       z53       x54       y54       z54
# 150095 -0.037794  0.303840  0.616979 -0.037350  0.316877  0.597338 -0.033791
# 150096 -0.056327  0.279851  0.691119 -0.060445  0.289750  0.684217 -0.059406
# 150097 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150098 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150099 -0.038810  0.246614  0.893922 -0.036005  0.250141  0.914375 -0.030636
#
# [5 rows x 163 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum().sum()
# Out:
# 292635

# %%
print(df.isnull().sum())
# Out:
# class       0
# x1          0
# y1          0
# z1          0
# x2          0
#          ...
# y53      4645
# z53      4645
# x54      4645
# y54      4645
# z54      4645
# Length: 163, dtype: int64

# %%
df = pd.DataFrame(df)
df
# Out:
#        class        x1        y1        z1        x2        y2        z2  \
# 0          0  0.469715  0.440847 -1.146045  0.492933  0.367618 -1.074119
# 1          0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780
# 2          0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780
# 3          0  0.461313  0.441721 -0.895512  0.490067  0.364946 -0.815676
# 4          0  0.462009  0.434323 -0.954978  0.490552  0.357484 -0.868968
# ...      ...       ...       ...       ...       ...       ...       ...
# 150095    ไอ  0.528125  0.373132 -0.992049  0.547567  0.315567 -0.916250
# 150096    ไอ  0.525108  0.370276 -0.992426  0.546147  0.315484 -0.917663
# 150097    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150098    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150099    ไอ  0.524986  0.361204 -1.097511  0.544687  0.304384 -1.024949
#
#               x3        y3        z3  ...       z51       x52       y52  \
# 0       0.506275  0.367054 -1.074444  ... -0.053524  0.399725  0.730864
# 1       0.505930  0.352796 -0.929152  ... -0.048000  0.398512  0.606266
# 2       0.505930  0.352796 -0.929152  ... -0.048000  0.398512  0.606266
# 3       0.505128  0.363007 -0.816117  ... -0.038509  0.395845  0.572608
# 4       0.504614  0.355328 -0.869323  ... -0.038847  0.392572  0.538630
# ...          ...       ...       ...  ...       ...       ...       ...
# 150095  0.562286  0.317489 -0.916352  ... -0.028968  0.291391  0.640639
# 150096  0.561741  0.318271 -0.917825  ... -0.037876  0.269125  0.701057
# 150097  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150098  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150099  0.559115  0.306688 -1.025168  ... -0.031130  0.237031  0.866545
#
#              z52       x53       y53       z53       x54       y54       z54
# 0      -0.062620  0.427866  0.751528 -0.060393  0.447253  0.774449 -0.058090
# 1      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 2      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 3      -0.049951  0.427251  0.590068 -0.049887  0.448360  0.611298 -0.047701
# 4      -0.047879  0.424092  0.548410 -0.046750  0.444159  0.566794 -0.043640
# ...          ...       ...       ...       ...       ...       ...       ...
# 150095 -0.037794  0.303840  0.616979 -0.037350  0.316877  0.597338 -0.033791
# 150096 -0.056327  0.279851  0.691119 -0.060445  0.289750  0.684217 -0.059406
# 150097 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150098 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150099 -0.038810  0.246614  0.893922 -0.036005  0.250141  0.914375 -0.030636
#
# [150100 rows x 163 columns]

# %%
# remove NaN columns
df_drop_ax0 = df.dropna(axis=0)
df_drop_ax0
# Out:
#        class        x1        y1        z1        x2        y2        z2  \
# 0          0  0.469715  0.440847 -1.146045  0.492933  0.367618 -1.074119
# 1          0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780
# 2          0  0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780
# 3          0  0.461313  0.441721 -0.895512  0.490067  0.364946 -0.815676
# 4          0  0.462009  0.434323 -0.954978  0.490552  0.357484 -0.868968
# ...      ...       ...       ...       ...       ...       ...       ...
# 150095    ไอ  0.528125  0.373132 -0.992049  0.547567  0.315567 -0.916250
# 150096    ไอ  0.525108  0.370276 -0.992426  0.546147  0.315484 -0.917663
# 150097    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150098    ไอ  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253
# 150099    ไอ  0.524986  0.361204 -1.097511  0.544687  0.304384 -1.024949
#
#               x3        y3        z3  ...       z51       x52       y52  \
# 0       0.506275  0.367054 -1.074444  ... -0.053524  0.399725  0.730864
# 1       0.505930  0.352796 -0.929152  ... -0.048000  0.398512  0.606266
# 2       0.505930  0.352796 -0.929152  ... -0.048000  0.398512  0.606266
# 3       0.505128  0.363007 -0.816117  ... -0.038509  0.395845  0.572608
# 4       0.504614  0.355328 -0.869323  ... -0.038847  0.392572  0.538630
# ...          ...       ...       ...  ...       ...       ...       ...
# 150095  0.562286  0.317489 -0.916352  ... -0.028968  0.291391  0.640639
# 150096  0.561741  0.318271 -0.917825  ... -0.037876  0.269125  0.701057
# 150097  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150098  0.558664  0.314726 -0.981566  ... -0.033339  0.254433  0.791060
# 150099  0.559115  0.306688 -1.025168  ... -0.031130  0.237031  0.866545
#
#              z52       x53       y53       z53       x54       y54       z54
# 0      -0.062620  0.427866  0.751528 -0.060393  0.447253  0.774449 -0.058090
# 1      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 2      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 3      -0.049951  0.427251  0.590068 -0.049887  0.448360  0.611298 -0.047701
# 4      -0.047879  0.424092  0.548410 -0.046750  0.444159  0.566794 -0.043640
# ...          ...       ...       ...       ...       ...       ...       ...
# 150095 -0.037794  0.303840  0.616979 -0.037350  0.316877  0.597338 -0.033791
# 150096 -0.056327  0.279851  0.691119 -0.060445  0.289750  0.684217 -0.059406
# 150097 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150098 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150099 -0.038810  0.246614  0.893922 -0.036005  0.250141  0.914375 -0.030636
#
# [145455 rows x 163 columns]

# %%
df_drop_ax0.isnull().values.any()
# Out:
# False

# %%
print(df_drop_ax0.isnull().sum())
# Out:
# class    0
# x1       0
# y1       0
# z1       0
# x2       0
#         ..
# y53      0
# z53      0
# x54      0
# y54      0
# z54      0
# Length: 163, dtype: int64

# %%
feature = df_drop_ax0.iloc[:, 1:]
label = df_drop_ax0.iloc[:, 0]
print(f'Feature = {feature.shape}  ; Label = {label.shape}')
# Out:
# Feature = (145455, 162)  ; Label = (145455,)

# %%
label
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 150095    ไอ
# 150096    ไอ
# 150097    ไอ
# 150098    ไอ
# 150099    ไอ
# Name: class, Length: 145455, dtype: object

# %%
feature
# Out:
#               x1        y1        z1        x2        y2        z2        x3  \
# 0       0.469715  0.440847 -1.146045  0.492933  0.367618 -1.074119  0.506275
# 1       0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780  0.505930
# 2       0.470880  0.431583 -1.010670  0.493463  0.355553 -0.928780  0.505930
# 3       0.461313  0.441721 -0.895512  0.490067  0.364946 -0.815676  0.505128
# 4       0.462009  0.434323 -0.954978  0.490552  0.357484 -0.868968  0.504614
# ...          ...       ...       ...       ...       ...       ...       ...
# 150095  0.528125  0.373132 -0.992049  0.547567  0.315567 -0.916250  0.562286
# 150096  0.525108  0.370276 -0.992426  0.546147  0.315484 -0.917663  0.561741
# 150097  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253  0.558664
# 150098  0.527792  0.370975 -1.054370  0.544327  0.313867 -0.981253  0.558664
# 150099  0.524986  0.361204 -1.097511  0.544687  0.304384 -1.024949  0.559115
#
#               y3        z3        x4  ...       z51       x52       y52  \
# 0       0.367054 -1.074444  0.520200  ... -0.053524  0.399725  0.730864
# 1       0.352796 -0.929152  0.518936  ... -0.048000  0.398512  0.606266
# 2       0.352796 -0.929152  0.518936  ... -0.048000  0.398512  0.606266
# 3       0.363007 -0.816117  0.515710  ... -0.038509  0.395845  0.572608
# 4       0.355328 -0.869323  0.515255  ... -0.038847  0.392572  0.538630
# ...          ...       ...       ...  ...       ...       ...       ...
# 150095  0.317489 -0.916352  0.575725  ... -0.028968  0.291391  0.640639
# 150096  0.318271 -0.917825  0.575497  ... -0.037876  0.269125  0.701057
# 150097  0.314726 -0.981566  0.572358  ... -0.033339  0.254433  0.791060
# 150098  0.314726 -0.981566  0.572358  ... -0.033339  0.254433  0.791060
# 150099  0.306688 -1.025168  0.573416  ... -0.031130  0.237031  0.866545
#
#              z52       x53       y53       z53       x54       y54       z54
# 0      -0.062620  0.427866  0.751528 -0.060393  0.447253  0.774449 -0.058090
# 1      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 2      -0.058852  0.428957  0.621372 -0.059092  0.449393  0.640706 -0.057821
# 3      -0.049951  0.427251  0.590068 -0.049887  0.448360  0.611298 -0.047701
# 4      -0.047879  0.424092  0.548410 -0.046750  0.444159  0.566794 -0.043640
# ...          ...       ...       ...       ...       ...       ...       ...
# 150095 -0.037794  0.303840  0.616979 -0.037350  0.316877  0.597338 -0.033791
# 150096 -0.056327  0.279851  0.691119 -0.060445  0.289750  0.684217 -0.059406
# 150097 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150098 -0.041410  0.265023  0.817268 -0.038859  0.269435  0.841274 -0.033614
# 150099 -0.038810  0.246614  0.893922 -0.036005  0.250141  0.914375 -0.030636
#
# [145455 rows x 162 columns]

# %%
print(f'Feature = {feature.shape}  ; Label = {label.shape}')
print(set(label))
# Out:
# Feature = (145455, 162)  ; Label = (145455,)
# {'อิ', '2', '90', '10,000', 'อี', 'ณ', 'ง', '70', 'ฉ', 'ฎ', '50', 'ป', 'ฮ', '20', 'ฏ', 'ข', 'ฐ', '6', 'ฆ', '0', 'ฑ', '40', '80', 'ร', '3', '5', 'อื(คือ)', 'ช', '1,000', 'พ', '7', 'ไอ', 'อ', '100,000', 'ก', 'ถ', 'ผ', '1,000,000', 'ซ', 'ส', '30', 'น', 'ย', 'ค', '100', 'จ', 'ต', 'ท', 'ฌ', 'ญ', '60', 'ฒ', 'ด', 'บ', 'ฝ', '8', 'ภ', 'ศ', 'ษ', '10', 'ห', 'ใอ', 'โอ', '1', '9', 'ม', 'ว', '4', 'ล', 'ธ', 'อึ(นึก)', 'ฬ', 'ฟ'}

# %%
# !python3 -m pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, label,test_size=0.2, shuffle= True, random_state= 42)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (116364, 162) (29091, 162) (116364,) (29091,)

# %%
x_train /= 255.0
x_test /= 255.0

# %%
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, shuffle=True, random_state=42)
print('x_train = {}, x_val = {}, x_test = {}'.format(x_train.shape, x_val.shape, x_test.shape))
print('y_train = {}, y_val = {}, y_test = {}'.format(y_train.shape, y_val.shape, y_test.shape))
# Out:
# x_train = (116364, 162), x_val = (14545, 162), x_test = (14546, 162)
# y_train = (116364,), y_val = (14545,), y_test = (14546,)

# %%
# One-Hot encoding
x_val_class = pd.get_dummies(y_train).values
y_val_class = pd.get_dummies(y_val).values
print('x_train = {}, x_val = {}, x_test = {}'.format(x_train.shape, x_val.shape, x_test.shape))
print('y_train = {}, y_val = {}, y_test = {}'.format(y_train.shape, y_val.shape, y_test.shape))
print('x_val_class = {}, y_val_class = {}'.format(x_val_class.shape, y_val_class.shape))
print(set(y_val))
# Out:
# x_train = (116364, 162), x_val = (14545, 162), x_test = (14546, 162)
# y_train = (116364,), y_val = (14545,), y_test = (14546,)
# x_val_class = (116364, 73), y_val_class = (14545, 73)
# {'อิ', '2', '90', '10,000', 'อี', 'ณ', 'ง', '70', 'ฎ', 'ฉ', 'ป', 'ฮ', '50', '20', 'ฏ', 'ข', 'ฐ', '6', 'ฆ', '0', 'ฑ', '40', '80', 'ร', '3', 'อื(คือ)', '5', 'ช', '1,000', 'ไอ', '7', 'พ', 'อ', '100,000', 'ก', 'ผ', 'ถ', '1,000,000', 'ซ', 'ส', '30', 'น', 'ย', 'ค', 'จ', '100', 'ท', 'ต', 'ฌ', 'ญ', 'บ', 'ฒ', 'ฝ', 'ภ', '60', '8', 'ศ', 'ใอ', 'ห', '10', 'ษ', 'ด', 'โอ', '1', 'ว', 'ม', '9', '4', 'ล', 'ธ', 'อึ(นึก)', 'ฬ', 'ฟ'}

# %%
# !pip install keras
# !pip install --upgrade pip
# !python -m pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPool2D, Dropout, Flatten, AveragePooling2D
from tensorflow.keras.utils import Sequence
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, recall_score, precision_score
from sklearn.metrics import f1_score, accuracy_score
import plotly.figure_factory as ff
import plotly
import plotly.graph_objs as go
import pickle
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from statistics import mode, StatisticsError
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import time

# %%
x_train.shape[1]
# Out:
# 162

# %%
step = x_train.shape[1]

# %%
def LSTM_model_OneHand():
    model = Sequential()

    # model.add(LSTM(units = 32, input_shape=(step, 1), activation= 'tanh'))

    model.add(LSTM(units = 128, input_shape=(step, 1), activation= 'tanh', return_sequences= True))
    #model.add(LSTM(units = 64, activation='tanh', return_sequences=True))
    model.add(LSTM(units= 64, activation= 'tanh'))

    model.add(Flatten())
    model.add(Dense(units = 512, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units = 84, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units= 73, activation= 'softmax'))
    model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = LSTM_model_OneHand()
model.build()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 162, 128)          66560
#
#  lstm_9 (LSTM)               (None, 64)                49408
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 512)               33280
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 84)                43092
#
#  dropout_7 (Dropout)         (None, 84)                0
#
#  dense_11 (Dense)            (None, 73)                6205
#
# =================================================================
# Total params: 198,545
# Trainable params: 198,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
# DataGenerator
class DataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y


train_gen = DataGenerator(x_train, x_val_class, 8)
test_gen = DataGenerator(x_val, y_val_class, 8)

# %%
es = EarlyStopping(monitor='val_loss', verbose=1, patience=5) #
mc = ModelCheckpoint('TL1 tr301.h5', monitor='val_accuracy', verbose=1, save_best_only=True) #

My_model = model.fit(train_gen, epochs=50, verbose=1, validation_data=test_gen, callbacks=[es, mc])
# Out:
# Epoch 1/50
# 2022-12-05 18:54:34.654153: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.654645: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.676782: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.677367: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.700832: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.701207: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.723682: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.724165: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.746710: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.747300: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.770714: W tensorflow/compiler/xla/service/gpu/llvm_gpu_backend/gpu_backend_lib.cc:326] libdevice is required by this HLO module but was not found at ./libdevice.10.bc
# 2022-12-05 18:54:34.771076: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at xla_ops.cc:446 : INTERNAL: libdevice not found at ./libdevice.10.bc
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In [80], line 4
#       1 es = EarlyStopping(monitor='val_loss', verbose=1, patience=5) #
#       2 mc = ModelCheckpoint('TL1 tr301.h5', monitor='val_accuracy', verbose=1, save_best_only=True) #
# ----> 4 My_model = model.fit(train_gen, epochs=50, verbose=1, validation_data=test_gen, callbacks=[es, mc])
#
# File ~/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/jupyter/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# InternalError: Graph execution error:
#
# Detected at node 'StatefulPartitionedCall_11' defined at (most recent call last):
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/asyncio/base_events.py", line 1899, in _run_once
#       handle._run()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2940, in run_cell
#       result = self._run_cell(
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2995, in _run_cell
#       return runner(coro)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3194, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3373, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/JOBs/tmpdir/pbs.6306357.spcc-adm1/ipykernel_2310091/734595266.py", line 4, in <module>
#       My_model = model.fit(train_gen, epochs=50, verbose=1, validation_data=test_gen, callbacks=[es, mc])
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 527, in minimize
#       self.apply_gradients(grads_and_vars)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1140, in apply_gradients
#       return super().apply_gradients(grads_and_vars, name=name)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 634, in apply_gradients
#       iteration = self._internal_apply_gradients(grads_and_vars)
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1166, in _internal_apply_gradients
#       return tf.__internal__.distribute.interim.maybe_merge_call(
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1216, in _distributed_apply_gradients_fn
#       distribution.extended.update(
#     File "/home/s2120006/miniconda3/envs/jupyter/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1211, in apply_grad_to_update_var
#       return self._update_step_xla(grad, var, id(self._var_key(var)))
# Node: 'StatefulPartitionedCall_11'
# libdevice not found at ./libdevice.10.bc
# 	 [[{{node StatefulPartitionedCall_11}}]] [Op:__inference_train_function_30421]
