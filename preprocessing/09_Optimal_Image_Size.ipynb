# %%
import os
import shutil
import numpy as np
from PIL import Image
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
vision_folder = 'C:\\Users\\wutti\Desktop\Test Files\\'

# %%
for subtype_folder in os.listdir(vision_folder):
    yolo_subtype_path = vision_folder + subtype_folder + '\\'
    for mainfile_folder in os.listdir(yolo_subtype_path):
        yolo_mainfile_path = yolo_subtype_path + mainfile_folder + '\\'
        for subfile in os.listdir(yolo_mainfile_path):
            yolo_subfile_path = yolo_mainfile_path + subfile + '\\' + 'Humand hand' + '\\'
            vision_yolo_path = vision_folder + '\\' + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\' + 'Humand hand' + '\\'
            for yolo_folder in os.listdir(vision_yolo_path):
                vision_yolo_subfolder_path = vision_yolo_path + '\\' + yolo_folder + '\\'
                for vision_yolo_file in os.listdir(vision_yolo_subfolder_path):
                    vision_yolo_file_path = vision_folder  + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\Humand hand\\' + yolo_folder + '\\' + vision_yolo_file
                    # print(vision_yolo_file_path)
                    img = Image.open(vision_yolo_file_path)
                    width = img.width
                    height = img.height
                    print(f'Filename = {vision_yolo_file!r:10} , Width = {width:4}, Height = {height:4}')
print('Done...')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22076/187090587.py in <module>
#       6             yolo_subfile_path = yolo_mainfile_path + subfile + '\\' + 'Humand hand' + '\\'
#       7             vision_yolo_path = vision_folder + '\\' + subtype_folder + '\\' + mainfile_folder + '\\' + subfile + '\\' + 'Humand hand' + '\\'
# ----> 8             for yolo_folder in os.listdir(vision_yolo_path):
#       9                 vision_yolo_subfolder_path = vision_yolo_path + '\\' + yolo_folder + '\\'
#      10                 for vision_yolo_file in os.listdir(vision_yolo_subfolder_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\wutti\\Desktop\\Test Files\\\\start_rembg\\ตัวเลข\\2\\Humand hand\\'

# %%
# import matplotlib.pyplot as plt
# from PIL import Image, ImageOps
# import numpy as np
# %matplotlib inline
#
# img = plt.imread(path)
# plt.title('Original')
# plt.imshow(img)
# plt.show()
# print(img.shape)
# Out:
# (258, 133, 3)

# %%
# img_75 = cv2.resize(img, None, fx = 0.75, fy = 0.75)
# plt.imshow(img_75)
# plt.show()
# print(img_75.shape)
# Out:
# (194, 100, 3)

# %%
# img_resize = cv2.resize(img,(224,224))
# plt.title('Resize 224x224')
# plt.imshow(img_resize)
# plt.show()
# print(img.shape)
# Out:
# (258, 133, 3)
